# %% [markdown]
# <a href="https://colab.research.google.com/github/akbaryossy/dataset/blob/main/neural_network/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download dataset
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-11-16 18:05:22--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.136.128, 142.250.152.128, 209.85.200.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.136.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   194MB/s    in 0.3s
#
# 2021-11-16 18:05:22 (194 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/LidahBuaya_Kemangi_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/LidahBuaya_Kemangi_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'Lidah_Buaya')
train_dogs_dir = os.path.join(train_dir, 'Kemangi')

validation_cats_dir = os.path.join(validation_dir, 'Lidah_Buaya')
validation_dogs_dir = os.path.join(validation_dir, 'Kemangi')

# %%
# Cek penamaan image yang ada di folder train_cats_dir dan train_dogs_dir
print(os.listdir(train_cats_dir)[:10])
print(os.listdir(train_dogs_dir)[:10])
# Out:
# ['028.jpg', '021.jpg', '047.jpg', '033.jpg', '014.jpg', '046.jpg', '035.jpg', '041.jpg', '009.jpg', '002.jpg']
# ['099.jpg', '066.jpg', '80.jpg', '096.jpg', '077.jpg', '098.jpg', '068.jpg', '095.jpg', '084.jpg', '067.jpg']

# %%
# Cek jumlah data train dan data validation
print('total training Lidah_Buaya images:', len(os.listdir(train_cats_dir)))
print('total training Kemangi images:', len(os.listdir(train_dogs_dir)))
print('total validation Lidah_Buaya images:', len(os.listdir(validation_cats_dir)))
print('total validation Kemangi images:', len(os.listdir(validation_dogs_dir)))
# Out:
# total training Lidah_Buaya images: 50
# total training Kemangi images: 51
# total validation Lidah_Buaya images: 50
# total validation Kemangi images: 51

# %%
# Tampilkan 8 image per kelas dengan ukuran 4x4 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_cat_pix = [os.path.join(train_cats_dir, fname) 
                for fname in os.listdir(train_cats_dir)[pic_index-8:pic_index]]
next_dog_pix = [os.path.join(train_dogs_dir, fname) 
                for fname in os.listdir(train_dogs_dir)[pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %% [markdown]
# <h3>Data Preprocessing</h3>

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
# Out:
# Train Data =  (100, 150, 150, 3)
# Train Label =  (100,)
# Validation Data =  (100, 150, 150, 3)
# Validation Label =  (100,)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [255 255 255]
# Data setelah di-normalisasi  [1. 1. 1.]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[995:1005])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[995:1005])
# Out:
# Label sebelum di-encoder  []
# Label setelah di-encoder  []

# %% [markdown]
# <h3>Definisikan Model</h3>

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
# Buat model dengan 1 input layer, 1 hidden layer, dan 1 output layer
img_input = layers.Input(shape=(150, 150, 3)) # layer input
x = layers.Flatten()(img_input) # ubah dari matriks 150x150x3 menjadi vektor
x = layers.Dense(128, activation='relu')(x) # hidden layer 1 dengan 128 neuron
output = layers.Dense(1, activation='sigmoid')(x) # output layer dengan 1 neuron (binary)

# Definisikan modelnya
model = Model(img_input, output)

# %%
# Tampilkan model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  flatten (Flatten)           (None, 67500)             0
#
#  dense (Dense)               (None, 128)               8640128
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,640,257
# Trainable params: 8,640,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
H = model.fit(x_train, y_train, batch_size=20, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 117ms/step - loss: 51.1712 - acc: 0.4600 - val_loss: 0.1627 - val_acc: 0.9300
# Epoch 2/50
# 5/5 [==============================] - 0s 80ms/step - loss: 7.5081 - acc: 0.7600 - val_loss: 8.1845 - val_acc: 0.5100
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 4.2704 - acc: 0.7400 - val_loss: 1.6314 - val_acc: 0.8000
# Epoch 4/50
# 5/5 [==============================] - 0s 76ms/step - loss: 2.3279 - acc: 0.7500 - val_loss: 0.5399 - val_acc: 0.9200
# Epoch 5/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.1746 - acc: 0.8200 - val_loss: 1.9918 - val_acc: 0.8400
# Epoch 6/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6458 - acc: 0.8900 - val_loss: 0.0161 - val_acc: 1.0000
# Epoch 7/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3560 - acc: 0.9500 - val_loss: 0.0223 - val_acc: 0.9900
# Epoch 8/50
# 5/5 [==============================] - 0s 76ms/step - loss: 0.3011 - acc: 0.9500 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 9/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.5794 - acc: 0.9500 - val_loss: 8.8986e-04 - val_acc: 1.0000
# Epoch 10/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.3386 - acc: 0.9500 - val_loss: 7.5719e-04 - val_acc: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1.0189 - acc: 0.9200 - val_loss: 7.1436e-04 - val_acc: 1.0000
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 1.1008 - acc: 0.9000 - val_loss: 5.3560 - val_acc: 0.5600
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 4.6256 - acc: 0.6900 - val_loss: 0.1486 - val_acc: 0.9600
# Epoch 14/50
# 5/5 [==============================] - 0s 76ms/step - loss: 4.7741 - acc: 0.7100 - val_loss: 7.9225 - val_acc: 0.5400
# Epoch 15/50
# 5/5 [==============================] - 0s 77ms/step - loss: 6.1835 - acc: 0.6500 - val_loss: 5.6185e-04 - val_acc: 1.0000
# 5/5 [==============================] - 0s 75ms/step - loss: 1.8861e-04 - acc: 1.0000 - val_loss: 1.8684e-04 - val_acc: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1.8685e-04 - acc: 1.0000 - val_loss: 1.8392e-04 - val_acc: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1.8283e-04 - acc: 1.0000 - val_loss: 1.8174e-04 - val_acc: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1.8059e-04 - acc: 1.0000 - val_loss: 1.7955e-04 - val_acc: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.7887e-04 - acc: 1.0000 - val_loss: 1.7717e-04 - val_acc: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.7647e-04 - acc: 1.0000 - val_loss: 1.7498e-04 - val_acc: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 73ms/step - loss: 1.7388e-04 - acc: 1.0000 - val_loss: 1.7313e-04 - val_acc: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.7275e-04 - acc: 1.0000 - val_loss: 1.7097e-04 - val_acc: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.7009e-04 - acc: 1.0000 - val_loss: 1.6925e-04 - val_acc: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 84ms/step - loss: 1.6810e-04 - acc: 1.0000 - val_loss: 1.6771e-04 - val_acc: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1.6686e-04 - acc: 1.0000 - val_loss: 1.6598e-04 - val_acc: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1.6550e-04 - acc: 1.0000 - val_loss: 1.6420e-04 - val_acc: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.6381e-04 - acc: 1.0000 - val_loss: 1.6252e-04 - val_acc: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 78ms/step - loss: 1.6218e-04 - acc: 1.0000 - val_loss: 1.6099e-04 - val_acc: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.6098e-04 - acc: 1.0000 - val_loss: 1.5938e-04 - val_acc: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 73ms/step - loss: 1.5881e-04 - acc: 1.0000 - val_loss: 1.5817e-04 - val_acc: 1.0000

# %% [markdown]
# <h3>Evaluasi Model</h3>

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 50), H.history["val_acc"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
